# %%
from urllib.parse import urlparse

# result = urlparse("git@github.com:vc-mediary/mediary_ui.git")

result = urlparse("https://github.com/vc-mediary/mediary_ui.git")

print(result)
# Out:
# ParseResult(scheme='https', netloc='github.com', path='/vc-mediary/mediary_ui.git', params='', query='', fragment='')
